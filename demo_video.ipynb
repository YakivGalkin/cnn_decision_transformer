# %%
# %%capture
import sys
import os

if 'google.colab' in sys.modules:
  if not os.path.exists('/content/.already_installed'):
    # !git clone https://github.com/YakivGalkin/cnn_decision_transformer
    # !apt-get install -y swig
    # !pip install -r cnn_decision_transformer/requirements.txt
    with open('/content/.already_installed', 'w') as f:
        f.write('done')
  # %cd /content/cnn_decision_transformer

# %%
import os
import random
import torch
from utils.env_driver import SimplePolicyEnvDriver, TransformerEnvDriver
from utils.seed_all import seed_everything
from utils.video import record_drive_video, get_video_tag
from stable_baselines3 import DQN
import gymnasium as gym
import utils.storage as storage
from IPython.display import HTML
import warnings
warnings.filterwarnings('ignore')

# %%
seed_everything()
env = gym.make('CarRacing-v2', continuous=False, ) #render_mode='human'

dqn_model = storage.get_pretrained_model(DQN,  'dql_car_racing.pt')
env_driver = SimplePolicyEnvDriver(dqn_model)

video_file = record_drive_video(env_driver=env_driver, file_name="dqn_01.mp4")
HTML(get_video_tag(video_file))
# Out:
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (400, 600) to (400, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
# Video saved to ./recorded_videos/dqn_01.mp4
# <video width="640" height="480" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
seed_everything()
env = gym.make('CarRacing-v2', continuous=False, ) #render_mode='human'

model = torch.load(storage.get_downloaded_model_file('vdt_001.pth'), map_location=torch.device('cpu'))
env_driver = TransformerEnvDriver(model, target_return_value = 950)

video_file = record_drive_video(env_driver=env_driver, file_name="vdt_01.mp4")
HTML(get_video_tag(video_file) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jacob/Documents/T/cnn_decision_transformer/DEMO_video.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/Users/jacob/Documents/T/cnn_decision_transformer/DEMO_video.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> seed_everything()
#       <a href='vscode-notebook-cell:/Users/jacob/Documents/T/cnn_decision_transformer/DEMO_video.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> env = gym.make('CarRacing-v2', continuous=False, ) #render_mode='human'
# ----> <a href='vscode-notebook-cell:/Users/jacob/Documents/T/cnn_decision_transformer/DEMO_video.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> env_driver = TransformerEnvDriver(model, 950)
#       <a href='vscode-notebook-cell:/Users/jacob/Documents/T/cnn_decision_transformer/DEMO_video.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> model = torch.load(storage.get_downloaded_model_file('vdt_001.pth'), map_location=torch.device('cpu'))
#       <a href='vscode-notebook-cell:/Users/jacob/Documents/T/cnn_decision_transformer/DEMO_video.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> video_file = record_drive_video(env_driver=env_driver, file_name="vdt_01.mp4")
#
# NameError: name 'model' is not defined

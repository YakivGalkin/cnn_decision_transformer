# %% [markdown]
# ### Introduction
#
# This notebook is intended to train a Decision Transformer using offline data gathered from exploring the CarRacing-v2 environment with a pre-trained DQN model.

# %% [markdown]
# ### Install initial environment in Google Colab

# %%
import sys
import os

if 'google.colab' in sys.modules:
  if not os.path.exists('/content/.already_installed'):
    # !git clone https://github.com/YakivGalkin/cnn_decision_transformer
    # !apt-get install -y swig
    # !pip install -r cnn_decision_transformer/requirements.txt
    with open('/content/.already_installed', 'w') as f:
        f.write('done')
  # %cd /content/cnn_decision_transformer
# Out:
# Cloning into 'cnn_decision_transformer'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 82 (delta 40), reused 53 (delta 17), pack-reused 0
# Receiving objects: 100% (82/82), 1.31 MiB | 1.74 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (466 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting box2d-py (from -r cnn_decision_transformer/requirements.txt (line 1))
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gymnasium[box2d] (from -r cnn_decision_transformer/requirements.txt (line 2))
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 48.5 MB/s eta 0:00:00
# Collecting stable-baselines3[extra] (from -r cnn_decision_transformer/requirements.txt (line 3))
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from -r cnn_decision_transformer/requirements.txt (line 4)) (0.10.2)
# Collecting wandb (from -r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.5 MB/s eta 0:00:00
# Collecting datasets (from -r cnn_decision_transformer/requirements.txt (line 6))
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 45.8 MB/s eta 0:00:00
# Collecting transformers (from -r cnn_decision_transformer/requirements.txt (line 7))
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 109.7 MB/s eta 0:00:00
# Collecting accelerate (from -r cnn_decision_transformer/requirements.txt (line 8))
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from -r cnn_decision_transformer/requirements.txt (line 9)) (3.9.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from -r cnn_decision_transformer/requirements.txt (line 10)) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from -r cnn_decision_transformer/requirements.txt (line 11)) (0.4.9)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r cnn_decision_transformer/requirements.txt (line 2)) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r cnn_decision_transformer/requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r cnn_decision_transformer/requirements.txt (line 2)) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[box2d]->-r cnn_decision_transformer/requirements.txt (line 2))
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting box2d-py (from -r cnn_decision_transformer/requirements.txt (line 1))
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 47.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r cnn_decision_transformer/requirements.txt (line 2)) (2.5.2)
# Collecting swig==4.* (from gymnasium[box2d]->-r cnn_decision_transformer/requirements.txt (line 2))
#   Downloading swig-4.1.1.post0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 96.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.1.0+cu118)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (4.8.0.76)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.14.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (13.6.0)
# Collecting shimmy[atari]~=1.1.0 (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3))
#   Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3))
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->-r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (2.31.0)
# Collecting sentry-sdk>=1.0.0 (from wandb->-r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 32.0 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->-r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (6.0.1)
# Collecting setproctitle (from wandb->-r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (3.20.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->-r cnn_decision_transformer/requirements.txt (line 6))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (3.4.1)
# Collecting multiprocess (from datasets->-r cnn_decision_transformer/requirements.txt (line 6))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets->-r cnn_decision_transformer/requirements.txt (line 6))
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r cnn_decision_transformer/requirements.txt (line 7)) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r cnn_decision_transformer/requirements.txt (line 7)) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers->-r cnn_decision_transformer/requirements.txt (line 7))
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 114.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r cnn_decision_transformer/requirements.txt (line 7))
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 96.4 MB/s eta 0:00:00
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3))
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 48.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r cnn_decision_transformer/requirements.txt (line 6)) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->-r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r cnn_decision_transformer/requirements.txt (line 5)) (2023.7.22)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.1.0->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3))
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.0.1)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets->-r cnn_decision_transformer/requirements.txt (line 6))
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (6.1.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r cnn_decision_transformer/requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]->-r cnn_decision_transformer/requirements.txt (line 3)) (3.2.2)
# Building wheels for collected packages: box2d-py, AutoROM.accept-rom-license
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349114 sha256=40d3d03dceeb94bf128b1b710272daabc1c5bf7506623530c777b2df71a050e4
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=21ef3134f0c494c991318d0002368111fc95e22b733ea6f77c92af20346fe753
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built box2d-py AutoROM.accept-rom-license
# Installing collected packages: swig, farama-notifications, box2d-py, smmap, setproctitle, sentry-sdk, safetensors, gymnasium, docker-pycreds, dill, ale-py, shimmy, multiprocess, huggingface-hub, gitdb, AutoROM.accept-rom-license, autorom, tokenizers, stable-baselines3, GitPython, accelerate, wandb, transformers, datasets
# Successfully installed AutoROM.accept-rom-license-0.6.1 GitPython-3.1.40 accelerate-0.24.1 ale-py-0.8.1 autorom-0.6.1 box2d-py-2.3.5 datasets-2.14.6 dill-0.3.7 docker-pycreds-0.4.0 farama-notifications-0.0.4 gitdb-4.0.11 gymnasium-0.29.1 huggingface-hub-0.17.3 multiprocess-0.70.15 safetensors-0.4.0 sentry-sdk-1.34.0 setproctitle-1.3.3 shimmy-1.1.0 smmap-5.0.1 stable-baselines3-2.1.0 swig-4.1.1.post0 tokenizers-0.14.1 transformers-4.35.0 wandb-0.16.0
# /content/cnn_decision_transformer

# %% [markdown]
# ### Load Dataset

# %%
#car_racing_15_100
#offline_car_racing_150_1000

import utils.storage as storage
features = storage.load_dataset('offline_car_racing_150_1000')
print(len(features["observations"]))
# Out:
# Downloading file from https://storage.googleapis.com/yakiv-dt-public/datasets/offline_car_racing_150_1000.hdf5 to ./downloaded_datasets/offline_car_racing_150_1000.hdf5
# Download complete.
# 150

# %%
import gymnasium as gym
env =  gym.make('CarRacing-v2', continuous=False) #, render_mode='human'

# %%
from dataclasses import asdict, dataclass


@dataclass
class TrainConfig:
    num_train_epochs: int = 5000
    max_ep_len: int = 1000
    max_length: int = 10
    rtg_gamma: float = 1.0

    prefix: str = 'DT'
    log_interval: int = 50
    save_steps: int = 1000
    per_device_train_batch_size: int = 32
    learning_rate: float = 0.0001
    weight_decay: float = 0.0001
    warmup_ratio: float = 0.1
    max_grad_norm: float = 0.25

trainConfig = TrainConfig()

# %%
import wandb
os.environ["WANDB_DISABLED"] = "false"
os.environ['WANDB_NOTEBOOK_NAME'] = 'DT_train.ipynb'
os.environ["WANDB_LOG_MODEL"] = "checkpoint"

#wandb.login(key="f060d3284088ffaf4624e2de8b236f39711a99a2") # move to .env!
wandb.init( name = "vdt_001",
           mode="online",
           entity="yakiv",
            project="VDT",
            #resume= "allow"
            config=asdict(trainConfig)
           )
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find DT_train.ipynb.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/content/cnn_decision_transformer/wandb/run-20231109_031345-ue7wn3vp</code>
# Syncing run <strong><a href='https://wandb.ai/yakiv/VDT/runs/ue7wn3vp' target="_blank">vdt_001</a></strong> to <a href='https://wandb.ai/yakiv/VDT' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yakiv/VDT' target="_blank">https://wandb.ai/yakiv/VDT</a>
#  View run at <a href='https://wandb.ai/yakiv/VDT/runs/ue7wn3vp' target="_blank">https://wandb.ai/yakiv/VDT/runs/ue7wn3vp</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/yakiv/VDT/runs/ue7wn3vp?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ### Train

# %%
from visual_decision_transformer.visual_decision_transformer_trainable import VisualDecisionTransformerGymDataCollator, TrainableVisualDecisionTransformer
from visual_decision_transformer.configuration import DecisionTransformerConfig
from utils.dataset_wrappers import DummyDataset
from utils.dataset_wrappers import CarRacingFeatureDataset
from transformers import Trainer, TrainingArguments

feature_dataset = CarRacingFeatureDataset(src=features)
collator = VisualDecisionTransformerGymDataCollator(feature_dataset, max_len=trainConfig.max_length,   max_ep_len=trainConfig.max_ep_len,)

dt_config = DecisionTransformerConfig(state_dim=collator.state_dim, act_dim=collator.act_dim,
                                      max_length = trainConfig.max_length,
                                      max_ep_len = trainConfig.max_ep_len,
                                      )

model = TrainableVisualDecisionTransformer(dt_config)


training_args = TrainingArguments(
    output_dir="output/",
    report_to="wandb",
    save_steps= trainConfig.save_steps,
    remove_unused_columns=False,
    optim="adamw_torch",
    num_train_epochs=trainConfig.num_train_epochs,
    per_device_train_batch_size= trainConfig.per_device_train_batch_size,
    learning_rate= trainConfig.learning_rate,
    weight_decay= trainConfig.weight_decay,
    warmup_ratio= trainConfig.warmup_ratio,
    max_grad_norm= trainConfig.max_grad_norm,
    logging_steps= trainConfig.log_interval,
)



trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=DummyDataset(len(feature_dataset)), #there is a 'hack'  - no need to pass actual data
    data_collator=collator,

)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes
# Downloading file from https://storage.googleapis.com/yakiv-dt-public/models/nature_cnn_dql_pretrained.pt to ./downloaded_models/nature_cnn_dql_pretrained.pt
# Download complete.
#     <div>
#
#       <progress value='25000' max='25000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25000/25000 16:54, Epoch 5000/5000]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.638200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.543500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.409000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.302700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.206100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.129500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.074000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.020100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.964800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.936000</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.902000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.861900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.840000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.810600</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.779100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.754300</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.725300</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.708400</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.697700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.677400</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.667300</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.641900</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.616100</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.604800</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.611800</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.593300</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.579600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.573000</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.552000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.544500</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.531400</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.526600</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.530100</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.506900</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.506600</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.506500</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.495400</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.483600</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.476100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.472800</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.471200</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.449200</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.438400</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.441300</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.443700</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.425300</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.435000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.435100</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.428300</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.415900</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.411000</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.420600</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.399800</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.396400</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.394100</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.381900</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.389900</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.373600</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.368900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.359800</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.359400</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.367400</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.342300</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.347800</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.352900</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.342400</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.346700</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.323700</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.317000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.328300</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.327900</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.307000</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.306400</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.309000</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.296100</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.294100</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.300500</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.295500</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.303000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.293600</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.294800</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.288300</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.278800</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.276900</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.275100</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.274000</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.271900</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.260000</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.253800</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.255400</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.263000</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.257100</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.258900</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.249400</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.238300</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.244800</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.243000</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.240100</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.243700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.233100</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>0.235300</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.214200</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>0.238000</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.223000</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>0.231600</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.210800</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>0.214600</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.230800</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>0.214300</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.204500</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>0.205600</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.215300</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>0.207000</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.209000</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>0.198700</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.206800</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>0.195400</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.193100</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>0.205700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.193300</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>0.192900</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.195200</t
# wandb: Adding directory to artifact (./output/checkpoint-1000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-2000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-3000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-4000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-5000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-6000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-7000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-8000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-9000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-10000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-11000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-12000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-13000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-14000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-15000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-16000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-17000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-18000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-19000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-20000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-21000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-22000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-23000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-24000)... Done. 0.1s
# wandb: Adding directory to artifact (./output/checkpoint-25000)... Done. 0.1s
# TrainOutput(global_step=25000, training_loss=0.15604460973203182, metrics={'train_runtime': 1022.7397, 'train_samples_per_second': 733.324, 'train_steps_per_second': 24.444, 'total_flos': 7.950956820028232e+18, 'train_loss': 0.15604460973203182, 'epoch': 5000.0})

# %%
import torch
torch.save(model, 'model_tr.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# !gcloud auth login
# !gcloud config set project clever-393810
#!gcloud auth list
#!gcloud storage buckets list
# !gsutil cp ./model_tr.pth gs://yakiv-dt-public/datasets/model_tr.pth
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=tlgYcz8xQMcs5GgALY9WE7wCvvUvuJ&prompt=consent&access_type=offline&code_challenge=-rYRMTPXM4jCfN5R1gTg1m8cWpNHnvm3FjMPpE1j1GM&code_challenge_method=S256
#
# Enter authorization code: 4/0AfJohXmryVygAWq69-4X4HUSF4pkeFFRJ3d6RrHnj0jGAbVcr4eU7ghn3QJ7fakgx_3Miw
#
# You are now logged in as [yakiv@flutterbase.com].
# Your current project is [None].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID
# Updated property [core/project].
# Copying file://./model_tr.pth [Content-Type=application/octet-stream]...
# -
# Operation completed over 1 objects/28.6 MiB.
